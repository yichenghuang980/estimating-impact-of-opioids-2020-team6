# %%
# Load the required packages needed for performing data merging
# %load_ext lab_black
import pandas as pd
import numpy as np
# Out:
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black

# %%
# Load shipment csv
ship = pd.read_csv(
    "C:/Users/Dean Huang/estimating-impact-of-opioids-2020-team6/00_source/SHIPMENT_agg.csv",
    sep=",",
)
# Check if there are anu duuplicate values
assert not ship.duplicated().any()

# Check if there are any null values
ship.isnull().any()
# Out:
# BUYER_STATE     False
# BUYER_COUNTY    False
# YEAR/MONTH      False
# MME             False
# dtype: bool

# %%
# Check the format of dataframe is correct
ship.head()
# Out:
#   BUYER_STATE BUYER_COUNTY  YEAR/MONTH            MME
# 0          FL      ALACHUA        2006   82596.618688
# 1          FL      ALACHUA        2007   95259.627977
# 2          FL      ALACHUA        2008  114675.221922
# 3          FL      ALACHUA        2009  141281.048185
# 4          FL      ALACHUA        2010  150910.785876

# %%
# Create a new column that only has Year (for merging)
ship["Year"] = ship["YEAR/MONTH"].astype(str).str[:4].astype(int)
ship[ship["BUYER_STATE"] == "WA"]
# Out:
#       BUYER_STATE BUYER_COUNTY  YEAR/MONTH      MME  Year
# 49987          WA        ADAMS       20061   211.94  2006
# 49988          WA        ADAMS       20062   202.97  2006
# 49989          WA        ADAMS       20063   175.37  2006
# 49990          WA        ADAMS       20064   213.54  2006
# 49991          WA        ADAMS       20065   187.66  2006
# ...           ...          ...         ...      ...   ...
# 53258          WA       YAKIMA      201111  6265.72  2011
# 53259          WA       YAKIMA      201112  6589.18  2011
# 53260          WA       YAKIMA      201210  7325.65  2012
# 53261          WA       YAKIMA      201211  6702.34  2012
# 53262          WA       YAKIMA      201212  6745.28  2012
#
# [3276 rows x 5 columns]

# %%
# Create a dictionary fpr mapping States to its abbreviation
States = {
    "FL": "Florida",
    "LA": "Louisiana",
    "MS": "Mississippi",
    "SC": "South Carolina",
    "WA": "Washington",
    "OR": "Oregon",
    "CO": "Colorado",
    "CA": "California",
    "TX": "Texas",
    "AR": "Arkansas",
    "NM": "New Mexico",
    "KS": "Kansas",
}
ship["FULL_STATES"] = ship["BUYER_STATE"].replace(States)
ship["FULL_STATES"].unique()
# Out:
# array(['Florida', 'Louisiana', 'Mississippi', 'South Carolina',
#        'Arkansas', 'Kansas', 'New Mexico', 'Texas', 'California',
#        'Colorado', 'Oregon', 'Washington'], dtype=object)

# %%
# Check if there are any null values
ship["FULL_STATES"].isnull().any()
# Out:
# False

# %%
# Load population 2000~2010 CSV
pop0 = pd.read_csv(
    "C:/Users/Dean Huang/estimating-impact-of-opioids-2020-team6/00_source/CensusEstimates2000-2010.csv",
    sep=",",
    encoding="ISO-8859-1",
)
pop0.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    ESTIMATESBASE2000  POPESTIMATE2000  POPESTIMATE2001  POPESTIMATE2002  \
# 0            4447207          4452173          4467634          4480089
# 1              43751            44021            44889            45909
# 2             140416           141342           144875           147957
# 3              29042            29015            28863            28653
# 4              19856            19913            21028            21199
#
#    POPESTIMATE2003  POPESTIMATE2004  POPESTIMATE2005  POPESTIMATE2006  \
# 0          4503491          4530729          4569805          4628981
# 1            46800            48366            49676            51328
# 2           151509           156266           162183           168121
# 3            28594            28287            28027            27861
# 4            21399            21721            22042            22099
#
#    POPESTIMATE2007  POPESTIMATE2008  POPESTIMATE2009  CENSUS2010POP  \
# 0          4672840          4718206          4757938        4779736
# 1            52405            53277            54135          54571
# 2           172404           175827           179406         182265
# 3            27757            27808            27657          27457
# 4            22438            22705            22941          22915
#
#    POPESTIMATE2010
# 0          4785298
# 1            54632
# 2           183195
# 3            27411
# 4            22867

# %%
# Load population 2010~2019 CSV
pop1 = pd.read_csv(
    "C:/Users/Dean Huang/estimating-impact-of-opioids-2020-team6/00_source/CensusEstimates2010-2019 (Ship).csv",
    sep=",",
    encoding="ISO-8859-1",
)
pop1.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# 0        4779736            4780125          4785437          4799069
# 1          54571              54597            54773            55227
# 2         182265             182265           183112           186558
# 3          27457              27455            27327            27341
# 4          22915              22915            22870            22745
#
#    POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  \
# 0          4815588          4830081          4841799          4852347
# 1            54954            54727            54893            54864
# 2           190145           194885           199183           202939
# 3            27169            26937            26755            26283
# 4            22667            22521            22553            22566
#
#    POPESTIMATE2016  POPESTIMATE2017  POPESTIMATE2018  POPESTIMATE2019
# 0          4863525          4874486          4887681          4903185
# 1            55243            55390            55533            55869
# 2           207601           212521           217855           223234
# 3            25806            25157            24872            24686
# 4            22586            22550            22367            22394

# %%
# Drop ESTIMATEBASE2000 because we are using CENSUS2000POP
pop0 = pop0.drop(["ESTIMATESBASE2000", "CENSUS2010POP", "POPESTIMATE2010"], axis=1)
pop0.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    POPESTIMATE2000  POPESTIMATE2001  POPESTIMATE2002  POPESTIMATE2003  \
# 0          4452173          4467634          4480089          4503491
# 1            44021            44889            45909            46800
# 2           141342           144875           147957           151509
# 3            29015            28863            28653            28594
# 4            19913            21028            21199            21399
#
#    POPESTIMATE2004  POPESTIMATE2005  POPESTIMATE2006  POPESTIMATE2007  \
# 0          4530729          4569805          4628981          4672840
# 1            48366            49676            51328            52405
# 2           156266           162183           168121           172404
# 3            28287            28027            27861            27757
# 4            21721            22042            22099            22438
#
#    POPESTIMATE2008  POPESTIMATE2009
# 0          4718206          4757938
# 1            53277            54135
# 2           175827           179406
# 3            27808            27657
# 4            22705            22941

# %%
# Drop ESTIMATEBASE2010 because we are using CENSUS2010POP
pop1 = pop1.drop(["ESTIMATESBASE2010", "POPESTIMATE2010"], axis=1)
# Change CENSUS2010POP  to CENSUS2010
pop1.rename(columns={"CENSUS2010POP": "CENSUS2010"}, inplace=True)
pop1.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010  POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# 0     4779736          4799069          4815588          4830081
# 1       54571            55227            54954            54727
# 2      182265           186558           190145           194885
# 3       27457            27341            27169            26937
# 4       22915            22745            22667            22521
#
#    POPESTIMATE2014  POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017  \
# 0          4841799          4852347          4863525          4874486
# 1            54893            54864            55243            55390
# 2           199183           202939           207601           212521
# 3            26755            26283            25806            25157
# 4            22553            22566            22586            22550
#
#    POPESTIMATE2018  POPESTIMATE2019
# 0          4887681          4903185
# 1            55533            55869
# 2           217855           223234
# 3            24872            24686
# 4            22367            22394

# %%
# Subset only the states we are interested
States = [
    "Florida",
    "Louisiana",
    "Mississippi",
    "South Carolina",
    "Washington",
    "Oregon",
    "Colorado",
    "California",
    "Texas",
    "Arkansas",
    "New Mexico",
    "Kansas",
]
pop0_final = pop0[pop0["STNAME"].isin(States) == True]
pop1_final = pop1[pop1["STNAME"].isin(States) == True]

# %%
# Check the subset datafram only contain the states mentioned in the list
pop0_final["STNAME"].unique()
# Out:
# array(['Arkansas', 'California', 'Colorado', 'Florida', 'Kansas',
#        'Louisiana', 'Mississippi', 'New Mexico', 'Oregon',
#        'South Carolina', 'Texas', 'Washington'], dtype=object)

# %%
# Check the subset datafram only contain the states mentioned in the list
pop1_final["STNAME"].unique()
# Out:
# array(['Arkansas', 'California', 'Colorado', 'Florida', 'Kansas',
#        'Louisiana', 'Mississippi', 'New Mexico', 'Oregon',
#        'South Carolina', 'Texas', 'Washington'], dtype=object)

# %%
# Melt the dataframe so all the years is in one column
pop0_melt = pd.melt(
    pop0_final,
    ["SUMLEV", "REGION", "DIVISION", "STATE", "COUNTY", "STNAME", "CTYNAME"],
    var_name="Year",
    value_name="Population",
)
pop0_melt.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY    STNAME          CTYNAME  \
# 0      40       3         7      5       0  Arkansas         Arkansas
# 1      50       3         7      5       1  Arkansas  Arkansas County
# 2      50       3         7      5       3  Arkansas    Ashley County
# 3      50       3         7      5       5  Arkansas    Baxter County
# 4      50       3         7      5       7  Arkansas    Benton County
#
#               Year  Population
# 0  POPESTIMATE2000     2678588
# 1  POPESTIMATE2000       20776
# 2  POPESTIMATE2000       24179
# 3  POPESTIMATE2000       38446
# 4  POPESTIMATE2000      154744

# %%
# Check population is correct after melting the dataframe
pop0_final[pop0_final["POPESTIMATE2000"] == 20776]
# Out:
#      SUMLEV  REGION  DIVISION  STATE  COUNTY    STNAME          CTYNAME  \
# 115      50       3         7      5       1  Arkansas  Arkansas County
#
#      POPESTIMATE2000  POPESTIMATE2001  POPESTIMATE2002  POPESTIMATE2003  \
# 115            20776            20593            20351            19981
#
#      POPESTIMATE2004  POPESTIMATE2005  POPESTIMATE2006  POPESTIMATE2007  \
# 115            19967            19954            19785            19434
#
#      POPESTIMATE2008  POPESTIMATE2009
# 115            19275            19134

# %%
# Melt the dataframe so all the years is in one column
pop1_melt = pd.melt(
    pop1_final,
    ["SUMLEV", "REGION", "DIVISION", "STATE", "COUNTY", "STNAME", "CTYNAME"],
    var_name="Year",
    value_name="Population",
)
pop1_melt.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY    STNAME          CTYNAME  \
# 0      40       3         7      5       0  Arkansas         Arkansas
# 1      50       3         7      5       1  Arkansas  Arkansas County
# 2      50       3         7      5       3  Arkansas    Ashley County
# 3      50       3         7      5       5  Arkansas    Baxter County
# 4      50       3         7      5       7  Arkansas    Benton County
#
#          Year  Population
# 0  CENSUS2010     2915918
# 1  CENSUS2010       19019
# 2  CENSUS2010       21853
# 3  CENSUS2010       41513
# 4  CENSUS2010      221339

# %%
# Check population is correct after melting the dataframe
pop1_final[pop1_final["CENSUS2010"] == 19019.0]
# Out:
#      SUMLEV  REGION  DIVISION  STATE  COUNTY    STNAME          CTYNAME  \
# 115      50       3         7      5       1  Arkansas  Arkansas County
#
#      CENSUS2010  POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# 115       19019            18871            18964            18755
#
#      POPESTIMATE2014  POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017  \
# 115            18479            18330            18154            17872
#
#      POPESTIMATE2018  POPESTIMATE2019
# 115            17726            17486

# %%
# Concatenate these two dataframes into 1
popc = pd.concat([pop0_melt, pop1_melt], axis=0)
popc.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY    STNAME          CTYNAME  \
# 0      40       3         7      5       0  Arkansas         Arkansas
# 1      50       3         7      5       1  Arkansas  Arkansas County
# 2      50       3         7      5       3  Arkansas    Ashley County
# 3      50       3         7      5       5  Arkansas    Baxter County
# 4      50       3         7      5       7  Arkansas    Benton County
#
#               Year  Population
# 0  POPESTIMATE2000     2678588
# 1  POPESTIMATE2000       20776
# 2  POPESTIMATE2000       24179
# 3  POPESTIMATE2000       38446
# 4  POPESTIMATE2000      154744

# %%
# Check everything is concatenate together
popc["Year"].unique()
# Out:
# array(['POPESTIMATE2000', 'POPESTIMATE2001', 'POPESTIMATE2002',
#        'POPESTIMATE2003', 'POPESTIMATE2004', 'POPESTIMATE2005',
#        'POPESTIMATE2006', 'POPESTIMATE2007', 'POPESTIMATE2008',
#        'POPESTIMATE2009', 'CENSUS2010', 'POPESTIMATE2011',
#        'POPESTIMATE2012', 'POPESTIMATE2013', 'POPESTIMATE2014',
#        'POPESTIMATE2015', 'POPESTIMATE2016', 'POPESTIMATE2017',
#        'POPESTIMATE2018', 'POPESTIMATE2019'], dtype=object)

# %%
# Remove county=0
popc = popc[popc["COUNTY"] != 0]
assert not (popc["COUNTY"] == 0).any()

# %%
# Remove the word 'County' & capitalize the name
# popc["CTYNAME"] = popc["CTYNAME"].str.replace("County", "").str.upper().replace(" ", "")
popc["CTYNAME"] = popc["CTYNAME"].str.rsplit(" ", 1)
popc["CTYNAME"] = popc["CTYNAME"].str[0]
popc["CTYNAME"] = popc["CTYNAME"].str.upper()
# popc["CTYNAME"] = popc["CTYNAME"].str.upper()
popc.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY    STNAME   CTYNAME  \
# 1      50       3         7      5       1  Arkansas  ARKANSAS
# 2      50       3         7      5       3  Arkansas    ASHLEY
# 3      50       3         7      5       5  Arkansas    BAXTER
# 4      50       3         7      5       7  Arkansas    BENTON
# 5      50       3         7      5       9  Arkansas     BOONE
#
#               Year  Population
# 1  POPESTIMATE2000       20776
# 2  POPESTIMATE2000       24179
# 3  POPESTIMATE2000       38446
# 4  POPESTIMATE2000      154744
# 5  POPESTIMATE2000       34051

# %%
# Only keep the four digits for year
popc["Year"] = popc["Year"].str[-4:].astype(int)

# %%
popc.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY    STNAME   CTYNAME  Year  \
# 1      50       3         7      5       1  Arkansas  ARKANSAS  2000
# 2      50       3         7      5       3  Arkansas    ASHLEY  2000
# 3      50       3         7      5       5  Arkansas    BAXTER  2000
# 4      50       3         7      5       7  Arkansas    BENTON  2000
# 5      50       3         7      5       9  Arkansas     BOONE  2000
#
#    Population
# 1       20776
# 2       24179
# 3       38446
# 4      154744
# 5       34051

# %%
# Remove unnecessary columns for population
drop = ["SUMLEV", "REGION", "DIVISION", "STATE", "COUNTY"]
popc1 = popc.drop(drop, axis=1)

# %%
popc["CTYNAME"].unique()
# Out:
# array(['ARKANSAS', 'ASHLEY', 'BAXTER', 'BENTON', 'BOONE', 'BRADLEY',
#        'CALHOUN', 'CARROLL', 'CHICOT', 'CLARK', 'CLAY', 'CLEBURNE',
#        'CLEVELAND', 'COLUMBIA', 'CONWAY', 'CRAIGHEAD', 'CRAWFORD',
#        'CRITTENDEN', 'CROSS', 'DALLAS', 'DESHA', 'DREW', 'FAULKNER',
#        'FRANKLIN', 'FULTON', 'GARLAND', 'GRANT', 'GREENE', 'HEMPSTEAD',
#        'HOT SPRING', 'HOWARD', 'INDEPENDENCE', 'IZARD', 'JACKSON',
#        'JEFFERSON', 'JOHNSON', 'LAFAYETTE', 'LAWRENCE', 'LEE', 'LINCOLN',
#        'LITTLE RIVER', 'LOGAN', 'LONOKE', 'MADISON', 'MARION', 'MILLER',
#        'MISSISSIPPI', 'MONROE', 'MONTGOMERY', 'NEVADA', 'NEWTON',
#        'OUACHITA', 'PERRY', 'PHILLIPS', 'PIKE', 'POINSETT', 'POLK',
#        'POPE', 'PRAIRIE', 'PULASKI', 'RANDOLPH', 'ST. FRANCIS', 'SALINE',
#        'SCOTT', 'SEARCY', 'SEBASTIAN', 'SEVIER', 'SHARP', 'STONE',
#        'UNION', 'VAN BUREN', 'WASHINGTON', 'WHITE', 'WOODRUFF', 'YELL',
#        'ALAMEDA', 'ALPINE', 'AMADOR', 'BUTTE', 'CALAVERAS', 'COLUSA',
#        'CONTRA COSTA', 'DEL NORTE', 'EL DORADO', 'FRESNO', 'GLENN',
#        'HUMBOLDT', 'IMPERIAL', 'INYO', 'KERN', 'KINGS', 'LAKE', 'LASSEN',
#        'LOS ANGELES', 'MADERA', 'MARIN', 'MARIPOSA', 'MENDOCINO',
#        'MERCED', 'MODOC', 'MONO', 'MONTEREY', 'NAPA', 'ORANGE', 'PLACER',
#        'PLUMAS', 'RIVERSIDE', 'SACRAMENTO', 'SAN BENITO',
#        'SAN BERNARDINO', 'SAN DIEGO', 'SAN FRANCISCO', 'SAN JOAQUIN',
#        'SAN LUIS OBISPO', 'SAN MATEO', 'SANTA BARBARA', 'SANTA CLARA',
#        'SANTA CRUZ', 'SHASTA', 'SIERRA', 'SISKIYOU', 'SOLANO', 'SONOMA',
#        'STANISLAUS', 'SUTTER', 'TEHAMA', 'TRINITY', 'TULARE', 'TUOLUMNE',
#        'VENTURA', 'YOLO', 'YUBA', 'ADAMS', 'ALAMOSA', 'ARAPAHOE',
#        'ARCHULETA', 'BACA', 'BENT', 'BOULDER', 'BROOMFIELD', 'CHAFFEE',
#        'CHEYENNE', 'CLEAR CREEK', 'CONEJOS', 'COSTILLA', 'CROWLEY',
#        'CUSTER', 'DELTA', 'DENVER', 'DOLORES', 'DOUGLAS', 'EAGLE',
#        'ELBERT', 'EL PASO', 'FREMONT', 'GARFIELD', 'GILPIN', 'GRAND',
#        'GUNNISON', 'HINSDALE', 'HUERFANO', 'KIOWA', 'KIT CARSON',
#        'LA PLATA', 'LARIMER', 'LAS ANIMAS', 'MESA', 'MINERAL', 'MOFFAT',
#        'MONTEZUMA', 'MONTROSE', 'MORGAN', 'OTERO', 'OURAY', 'PARK',
#        'PITKIN', 'PROWERS', 'PUEBLO', 'RIO BLANCO', 'RIO GRANDE', 'ROUTT',
#        'SAGUACHE', 'SAN JUAN', 'SAN MIGUEL', 'SEDGWICK', 'SUMMIT',
#        'TELLER', 'WELD', 'YUMA', 'ALACHUA', 'BAKER', 'BAY', 'BRADFORD',
#        'BREVARD', 'BROWARD', 'CHARLOTTE', 'CITRUS', 'COLLIER', 'DESOTO',
#        'DIXIE', 'DUVAL', 'ESCAMBIA', 'FLAGLER', 'GADSDEN', 'GILCHRIST',
#        'GLADES', 'GULF', 'HAMILTON', 'HARDEE', 'HENDRY', 'HERNANDO',
#        'HIGHLANDS', 'HILLSBOROUGH', 'HOLMES', 'INDIAN RIVER', 'LEON',
#        'LEVY', 'LIBERTY', 'MANATEE', 'MARTIN', 'MIAMI-DADE', 'NASSAU',
#        'OKALOOSA', 'OKEECHOBEE', 'OSCEOLA', 'PALM BEACH', 'PASCO',
#        'PINELLAS', 'PUTNAM', 'ST. JOHNS', 'ST. LUCIE', 'SANTA ROSA',
#        'SARASOTA', 'SEMINOLE', 'SUMTER', 'SUWANNEE', 'TAYLOR', 'VOLUSIA',
#        'WAKULLA', 'WALTON', 'ALLEN', 'ANDERSON', 'ATCHISON', 'BARBER',
#        'BARTON', 'BOURBON', 'BROWN', 'BUTLER', 'CHASE', 'CHAUTAUQUA',
#        'CHEROKEE', 'CLOUD', 'COFFEY', 'COMANCHE', 'COWLEY', 'DECATUR',
#        'DICKINSON', 'DONIPHAN', 'EDWARDS', 'ELK', 'ELLIS', 'ELLSWORTH',
#        'FINNEY', 'FORD', 'GEARY', 'GOVE', 'GRAHAM', 'GRAY', 'GREELEY',
#        'GREENWOOD', 'HARPER', 'HARVEY', 'HASKELL', 'HODGEMAN', 'JEWELL',
#        'KEARNY', 'KINGMAN', 'LABETTE', 'LANE', 'LEAVENWORTH', 'LINN',
#        'LYON', 'MCPHERSON', 'MARSHALL', 'MEADE', 'MIAMI', 'MITCHELL',
#        'MORRIS', 'MORTON', 'NEMAHA', 'NEOSHO', 'NESS', 'NORTON', 'OSAGE',
#        'OSBORNE', 'OTTAWA', 'PAWNEE', 'POTTAWATOMIE', 'PRATT', 'RAWLINS',
#        'RENO', 'REPUBLIC', 'RICE', 'RILEY', 'ROOKS', 'RUSH', 'RUSSELL',
#        'SEWARD', 'SHAWNEE', 'SHERIDAN', 'SHERMAN', 'SMITH', 'STAFFORD',
#        'STANTON', 'STEVENS', 'SUMNER', 'THOMAS', 'TREGO', 'WABAUNSEE',
#        'WALLACE', 'WICHITA', 'WILSON', 'WOODSON', 'WYANDOTTE', 'ACADIA',
#        'ASCENSION', 'ASSUMPTION', 'AVOYELLES', 'BEAUREGARD', 'BIENVILLE',
#        'BOSSIER', 'CADDO', 'CALCASIEU', 'CALDWELL', 'CAMERON',
#        'CATAHOULA', 'CLAIBORNE', 'CONCORDIA', 'DE SOTO',
#        'EAST BATON ROUGE', 'EAST CARROLL', 'EAST FELICIANA', 'EVANGELINE',
#        'IBERIA', 'IBERVILLE', 'JEFFERSON DAVIS', 'LAFOURCHE', 'LA SALLE',
#        'LIVINGSTON', 'MOREHOUSE', 'NATCHITOCHES', 'ORLEANS',
#        'PLAQUEMINES', 'POINTE COUPEE', 'RAPIDES', 'RED RIVER', 'RICHLAND',
#        'SABINE', 'ST. BERNARD', 'ST. CHARLES', 'ST. HELENA', 'ST. JAMES',
#        'ST. JOHN THE BAPTIST', 'ST. LANDRY', 'ST. MARTIN', 'ST. MARY',
#        'ST. TAMMANY', 'TANGIPAHOA', 'TENSAS', 'TERREBONNE', 'VERMILION',
#        'VERNON', 'WEBSTER', 'WEST BATON ROUGE', 'WEST CARROLL',
#        'WEST FELICIANA', 'WINN', 'ALCORN', 'AMITE', 'ATTALA', 'BOLIVAR',
#        'CHICKASAW', 'CHOCTAW', 'CLARKE', 'COAHOMA', 'COPIAH', 'COVINGTON',
#        'FORREST', 'GEORGE', 'GRENADA', 'HANCOCK', 'HARRISON', 'HINDS',
#        'HUMPHREYS', 'ISSAQUENA', 'ITAWAMBA', 'JASPER', 'JONES', 'KEMPER',
#        'LAMAR', 'LAUDERDALE', 'LEAKE', 'LEFLORE', 'LOWNDES', 'NESHOBA',
#        'NOXUBEE', 'OKTIBBEHA', 'PANOLA', 'PEARL RIVER', 'PONTOTOC',
#        'PRENTISS', 'QUITMAN', 'RANKIN', 'SHARKEY', 'SIMPSON', 'SUNFLOWER',
#        'TALLAHATCHIE', 'TATE', 'TIPPAH', 'TISHOMINGO', 'TUNICA',
#        'WALTHALL', 'WARREN', 'WAYNE', 'WILKINSON', 'WINSTON', 'YALOBUSHA',
#        'YAZOO', 'BERNALILLO', 'CATRON', 'CHAVES', 'CIBOLA', 'COLFAX',
#        'CURRY', 'DE BACA', 'DOÑA ANA', 'EDDY', 'GUADALUPE', 'HARDING',
#        'HIDALGO', 'LEA', 'LOS ALAMOS', 'LUNA', 'MCKINLEY', 'MORA', 'QUAY',
#        'RIO ARRIBA', 'ROOSEVELT', 'SANDOVAL', 'SANTA FE', 'SOCORRO',
#        'TAOS', 'TORRANCE', 'VALENCIA', 'CLACKAMAS', 'CLATSOP', 'COOS',
#        'CROOK', 'DESCHUTES', 'GILLIAM', 'HARNEY', 'HOOD RIVER',
#        'JOSEPHINE', 'KLAMATH', 'MALHEUR', 'MORROW', 'MULTNOMAH',
#        'TILLAMOOK', 'UMATILLA', 'WALLOWA', 'WASCO', 'WHEELER', 'YAMHILL',
#        'ABBEVILLE', 'AIKEN', 'ALLENDALE', 'BAMBERG', 'BARNWELL',
#        'BEAUFORT', 'BERKELEY', 'CHARLESTON', 'CHESTER', 'CHESTERFIELD',
#        'CLARENDON', 'COLLETON', 'DARLINGTON', 'DILLON', 'DORCHESTER',
#        'EDGEFIELD', 'FAIRFIELD', 'FLORENCE', 'GEORGETOWN', 'GREENVILLE',
#        'HAMPTON', 'HORRY', 'KERSHAW', 'LANCASTER', 'LAURENS', 'LEXINGTON',
#        'MCCORMICK', 'MARLBORO', 'NEWBERRY', 'OCONEE', 'ORANGEBURG',
#        'PICKENS', 'SALUDA', 'SPARTANBURG', 'WILLIAMSBURG', 'YORK',
#        'ANDREWS', 'ANGELINA', 'ARANSAS', 'ARCHER', 'ARMSTRONG',
#        'ATASCOSA', 'AUSTIN', 'BAILEY', 'BANDERA', 'BASTROP', 'BAYLOR',
#        'BEE', 'BELL', 'BEXAR', 'BLANCO', 'BORDEN', 'BOSQUE', 'BOWIE',
#        'BRAZORIA', 'BRAZOS', 'BREWSTER', 'BRISCOE', 'BROOKS', 'BURLESON',
#        'BURNET', 'CALLAHAN', 'CAMP', 'CARSON', 'CASS', 'CASTRO',
#        'CHAMBERS', 'CHILDRESS', 'COCHRAN', 'COKE', 'COLEMAN', 'COLLIN',
#        'COLLINGSWORTH', 'COLORADO', 'COMAL', 'CONCHO', 'COOKE', 'CORYELL',
#        'COTTLE', 'CRANE', 'CROCKETT', 'CROSBY', 'CULBERSON', 'DALLAM',
#        'DAWSON', 'DEAF SMITH', 'DENTON', 'DEWITT', 'DICKENS', 'DIMMIT',
#        'DONLEY', 'EASTLAND', 'ECTOR', 'ERATH', 'FALLS', 'FANNIN',
#        'FAYETTE', 'FISHER', 'FLOYD', 'FOARD', 'FORT BEND', 'FREESTONE',
#        'FRIO', 'GAINES', 'GALVESTON', 'GARZA', 'GILLESPIE', 'GLASSCOCK',
#        'GOLIAD', 'GONZALES', 'GRAYSON', 'GREGG', 'GRIMES', 'HALE', 'HALL',
#        'HANSFORD', 'HARDEMAN', 'HARDIN', 'HARRIS', 'HARTLEY', 'HAYS',
#        'HEMPHILL', 'HENDERSON', 'HILL', 'HOCKLEY', 'HOOD', 'HOPKINS',
#        'HOUSTON', 'HUDSPETH', 'HUNT', 'HUTCHINSON', 'IRION', 'JACK',
#        'JEFF DAVIS', 'JIM HOGG', 'JIM WELLS', 'KARNES', 'KAUFMAN',
#        'KENDALL', 'KENEDY', 'KENT', 'KERR', 'KIMBLE', 'KING', 'KINNEY',
#        'KLEBERG', 'KNOX', 'LAMB', 'LAMPASAS', 'LAVACA', 'LIMESTONE',
#        'LIPSCOMB', 'LIVE OAK', 'LLANO', 'LOVING', 'LUBBOCK', 'LYNN',
#        'MCCULLOCH', 'MCLENNAN', 'MCMULLEN', 'MASON', 'MATAGORDA',
#        'MAVERICK', 'MEDINA', 'MENARD', 'MIDLAND', 'MILAM', 'MILLS',
#        'MONTAGUE', 'MOORE', 'MOTLEY', 'NACOGDOCHES', 'NAVARRO', 'NOLAN',
#        'NUECES', 'OCHILTREE', 'OLDHAM', 'PALO PINTO', 'PARKER', 'PARMER',
#        'PECOS', 'POTTER', 'PRESIDIO', 'RAINS', 'RANDALL', 'REAGAN',
#        'REAL', 'REEVES', 'REFUGIO', 'ROBERTS', 'ROBERTSON', 'ROCKWALL',
#        'RUNNELS', 'RUSK', 'SAN AUGUSTINE', 'SAN JACINTO', 'SAN PATRICIO',
#        'SAN SABA', 'SCHLEICHER', 'SCURRY', 'SHACKELFORD', 'SHELBY',
#        'SOMERVELL', 'STARR', 'STEPHENS', 'STERLING', 'STONEWALL',
#        'SUTTON', 'SWISHER', 'TARRANT', 'TERRELL', 'TERRY', 'THROCKMORTON',
#        'TITUS', 'TOM GREEN', 'TRAVIS', 'TYLER', 'UPSHUR', 'UPTON',
#        'UVALDE', 'VAL VERDE', 'VAN ZANDT', 'VICTORIA', 'WALKER', 'WALLER',
#        'WARD', 'WEBB', 'WHARTON', 'WILBARGER', 'WILLACY', 'WILLIAMSON',
#        'WINKLER', 'WISE', 'WOOD', 'YOAKUM', 'YOUNG', 'ZAPATA', 'ZAVALA',
#        'ASOTIN', 'CHELAN', 'CLALLAM', 'COWLITZ', 'FERRY', 'GRAYS HARBOR',
#        'ISLAND', 'KITSAP', 'KITTITAS', 'KLICKITAT', 'LEWIS', 'OKANOGAN',
#        'PACIFIC', 'PEND OREILLE', 'PIERCE', 'SKAGIT', 'SKAMANIA',
#        'SNOHOMISH', 'SPOKANE', 'THURSTON', 'WAHKIAKUM', 'WALLA WALLA',
#        'WHATCOM', 'WHITMAN', 'YAKIMA', 'LASALLE'], dtype=object)

# %%
# Replace 'DEWITT' with 'DE WITT'
popc1["CTYNAME"].replace("DEWITT", "DE WITT", inplace=True)
popc1[popc1["CTYNAME"] == "DE WITT"]
# Out:
#      STNAME  CTYNAME  Year  Population
# 702   Texas  DE WITT  2000       19943
# 1637  Texas  DE WITT  2001       20066
# 2572  Texas  DE WITT  2002       20015
# 3507  Texas  DE WITT  2003       20034
# 4442  Texas  DE WITT  2004       20176
# 5377  Texas  DE WITT  2005       20342
# 6312  Texas  DE WITT  2006       20108
# 7247  Texas  DE WITT  2007       19961
# 8182  Texas  DE WITT  2008       19902
# 9117  Texas  DE WITT  2009       20048
# 702   Texas  DE WITT  2010       20097
# 1637  Texas  DE WITT  2011       20205
# 2572  Texas  DE WITT  2012       20358
# 3507  Texas  DE WITT  2013       20377
# 4442  Texas  DE WITT  2014       20518
# 5377  Texas  DE WITT  2015       20632
# 6312  Texas  DE WITT  2016       20623
# 7247  Texas  DE WITT  2017       20180
# 8182  Texas  DE WITT  2018       20106
# 9117  Texas  DE WITT  2019       20160

# %%
# Replace 'Doña Ana" with "DONA ANA"
popc1["CTYNAME"].replace("DOÑA ANA", "DONA ANA", inplace=True)
popc1[popc1["CTYNAME"] == "DONA ANA"]
# Out:
#           STNAME   CTYNAME  Year  Population
# 530   New Mexico  DONA ANA  2000      175098
# 1465  New Mexico  DONA ANA  2001      176496
# 2400  New Mexico  DONA ANA  2002      178464
# 3335  New Mexico  DONA ANA  2003      182045
# 4270  New Mexico  DONA ANA  2004      184939
# 5205  New Mexico  DONA ANA  2005      189199
# 6140  New Mexico  DONA ANA  2006      193701
# 7075  New Mexico  DONA ANA  2007      197853
# 8010  New Mexico  DONA ANA  2008      200855
# 8945  New Mexico  DONA ANA  2009      205401
# 530   New Mexico  DONA ANA  2010      209233
# 1465  New Mexico  DONA ANA  2011      213126
# 2400  New Mexico  DONA ANA  2012      214450
# 3335  New Mexico  DONA ANA  2013      214288
# 4270  New Mexico  DONA ANA  2014      213933
# 5205  New Mexico  DONA ANA  2015      214034
# 6140  New Mexico  DONA ANA  2016      214663
# 7075  New Mexico  DONA ANA  2017      216174
# 8010  New Mexico  DONA ANA  2018      217278
# 8945  New Mexico  DONA ANA  2019      218195

# %%
# Replace 'ST" with "SAINT"
popc1["CTYNAME"].replace("ST\.", "SAINT", regex=True, inplace=True)
popc1[popc1["CTYNAME"] == "SAINT FRANCIS"]
# Out:
#         STNAME        CTYNAME  Year  Population
# 62    Arkansas  SAINT FRANCIS  2000       29325
# 997   Arkansas  SAINT FRANCIS  2001       29072
# 1932  Arkansas  SAINT FRANCIS  2002       29023
# 2867  Arkansas  SAINT FRANCIS  2003       29170
# 3802  Arkansas  SAINT FRANCIS  2004       28905
# 4737  Arkansas  SAINT FRANCIS  2005       28639
# 5672  Arkansas  SAINT FRANCIS  2006       28496
# 6607  Arkansas  SAINT FRANCIS  2007       28394
# 7542  Arkansas  SAINT FRANCIS  2008       28110
# 8477  Arkansas  SAINT FRANCIS  2009       28336
# 62    Arkansas  SAINT FRANCIS  2010       28258
# 997   Arkansas  SAINT FRANCIS  2011       27994
# 1932  Arkansas  SAINT FRANCIS  2012       27992
# 2867  Arkansas  SAINT FRANCIS  2013       27508
# 3802  Arkansas  SAINT FRANCIS  2014       27088
# 4737  Arkansas  SAINT FRANCIS  2015       26651
# 5672  Arkansas  SAINT FRANCIS  2016       26347
# 6607  Arkansas  SAINT FRANCIS  2017       25997
# 7542  Arkansas  SAINT FRANCIS  2018       25509
# 8477  Arkansas  SAINT FRANCIS  2019       24994

# %%
# Replace 'SAINT JOHN THE BAPTIST" with "ST JOHN THE BAPTIST"
popc1["CTYNAME"].replace("SAINT JOHN THE BAPTIST", "ST JOHN THE BAPTIST", inplace=True)
popc1[popc1["CTYNAME"] == "ST JOHN THE BAPTIST"]
# Out:
#          STNAME              CTYNAME  Year  Population
# 422   Louisiana  ST JOHN THE BAPTIST  2000       43248
# 1357  Louisiana  ST JOHN THE BAPTIST  2001       43580
# 2292  Louisiana  ST JOHN THE BAPTIST  2002       43878
# 3227  Louisiana  ST JOHN THE BAPTIST  2003       44316
# 4162  Louisiana  ST JOHN THE BAPTIST  2004       44822
# 5097  Louisiana  ST JOHN THE BAPTIST  2005       45296
# 6032  Louisiana  ST JOHN THE BAPTIST  2006       47296
# 6967  Louisiana  ST JOHN THE BAPTIST  2007       47386
# 7902  Louisiana  ST JOHN THE BAPTIST  2008       46811
# 8837  Louisiana  ST JOHN THE BAPTIST  2009       46336
# 422   Louisiana  ST JOHN THE BAPTIST  2010       45924
# 1357  Louisiana  ST JOHN THE BAPTIST  2011       45066
# 2292  Louisiana  ST JOHN THE BAPTIST  2012       44719
# 3227  Louisiana  ST JOHN THE BAPTIST  2013       43570
# 4162  Louisiana  ST JOHN THE BAPTIST  2014       43714
# 5097  Louisiana  ST JOHN THE BAPTIST  2015       43523
# 6032  Louisiana  ST JOHN THE BAPTIST  2016       43401
# 6967  Louisiana  ST JOHN THE BAPTIST  2017       43328
# 7902  Louisiana  ST JOHN THE BAPTIST  2018       43119
# 8837  Louisiana  ST JOHN THE BAPTIST  2019       42837

# %%
# Replace 'LASALLE" with "LA SALLE"
popc1["CTYNAME"].replace("LASALLE", "LA SALLE", inplace=True)
popc1[popc1["CTYNAME"] == "LA SALLE"]
# Out:
#          STNAME   CTYNAME  Year  Population
# 404   Louisiana  LA SALLE  2000       14271
# 782       Texas  LA SALLE  2000        5898
# 1339  Louisiana  LA SALLE  2001       14207
# 1717      Texas  LA SALLE  2001        5934
# 2274  Louisiana  LA SALLE  2002       14359
# 2652      Texas  LA SALLE  2002        6098
# 3209  Louisiana  LA SALLE  2003       14356
# 3587      Texas  LA SALLE  2003        6169
# 4144  Louisiana  LA SALLE  2004       14366
# 4522      Texas  LA SALLE  2004        6322
# 5079  Louisiana  LA SALLE  2005       14313
# 5457      Texas  LA SALLE  2005        6542
# 6014  Louisiana  LA SALLE  2006       14519
# 6392      Texas  LA SALLE  2006        6549
# 6949  Louisiana  LA SALLE  2007       14570
# 7327      Texas  LA SALLE  2007        6675
# 7884  Louisiana  LA SALLE  2008       14667
# 8262      Texas  LA SALLE  2008        6653
# 8819  Louisiana  LA SALLE  2009       14717
# 9197      Texas  LA SALLE  2009        6771
# 404   Louisiana  LA SALLE  2010       14890
# 782       Texas  LA SALLE  2010        6886
# 1339  Louisiana  LA SALLE  2011       14941
# 1717      Texas  LA SALLE  2011        7002
# 2274  Louisiana  LA SALLE  2012       14862
# 2652      Texas  LA SALLE  2012        7157
# 3209  Louisiana  LA SALLE  2013       14821
# 3587      Texas  LA SALLE  2013        7444
# 4144  Louisiana  LA SALLE  2014       14875
# 4522      Texas  LA SALLE  2014        7481
# 5079  Louisiana  LA SALLE  2015       14979
# 5457      Texas  LA SALLE  2015        7637
# 6014  Louisiana  LA SALLE  2016       15022
# 6392      Texas  LA SALLE  2016        7596
# 6949  Louisiana  LA SALLE  2017       14887
# 7327      Texas  LA SALLE  2017        7530
# 7884  Louisiana  LA SALLE  2018       14901
# 8262      Texas  LA SALLE  2018        7493
# 8819  Louisiana  LA SALLE  2019       14892
# 9197      Texas  LA SALLE  2019        7520

# %%
# Replace 'DESOTO" with "DE SOTO"
popc1["CTYNAME"].replace("DESOTO", "DE SOTO", inplace=True)
popc1[popc1["CTYNAME"] == "DE SOTO"]
# Out:
#            STNAME  CTYNAME  Year  Population
# 213       Florida  DE SOTO  2000       32196
# 390     Louisiana  DE SOTO  2000       25502
# 456   Mississippi  DE SOTO  2000      108714
# 1148      Florida  DE SOTO  2001       32402
# 1325    Louisiana  DE SOTO  2001       25449
# 1391  Mississippi  DE SOTO  2001      113401
# 2083      Florida  DE SOTO  2002       32446
# 2260    Louisiana  DE SOTO  2002       25598
# 2326  Mississippi  DE SOTO  2002      118603
# 3018      Florida  DE SOTO  2003       33271
# 3195    Louisiana  DE SOTO  2003       25675
# 3261  Mississippi  DE SOTO  2003      124347
# 3953      Florida  DE SOTO  2004       33895
# 4130    Louisiana  DE SOTO  2004       25958
# 4196  Mississippi  DE SOTO  2004      130767
# 4888      Florida  DE SOTO  2005       33864
# 5065    Louisiana  DE SOTO  2005       26029
# 5131  Mississippi  DE SOTO  2005      136915
# 5823      Florida  DE SOTO  2006       34300
# 6000    Louisiana  DE SOTO  2006       26175
# 6066  Mississippi  DE SOTO  2006      145220
# 6758      Florida  DE SOTO  2007       34537
# 6935    Louisiana  DE SOTO  2007       26413
# 7001  Mississippi  DE SOTO  2007      150688
# 7693      Florida  DE SOTO  2008       34374
# 7870    Louisiana  DE SOTO  2008       26590
# 7936  Mississippi  DE SOTO  2008      156214
# 8628      Florida  DE SOTO  2009       34592
# 8805    Louisiana  DE SOTO  2009       26413
# 8871  Mississippi  DE SOTO  2009      159706
# 213       Florida  DE SOTO  2010       34862
# 390     Louisiana  DE SOTO  2010       26656
# 456   Mississippi  DE SOTO  2010      161252
# 1148      Florida  DE SOTO  2011       34845
# 1325    Louisiana  DE SOTO  2011       26779
# 1391  Mississippi  DE SOTO  2011      164075
# 2083      Florida  DE SOTO  2012       35005
# 2260    Louisiana  DE SOTO  2012       27023
# 2326  Mississippi  DE SOTO  2012      166426
# 3018      Florida  DE SOTO  2013       34905
# 3195    Louisiana  DE SOTO  2013       27089
# 3261  Mississippi  DE SOTO  2013      168370
# 3953      Florida  DE SOTO  2014       35338
# 4130    Louisiana  DE SOTO  2014       27061
# 4196  Mississippi  DE SOTO  2014      170760
# 4888      Florida  DE SOTO  2015       35648
# 5065    Louisiana  DE SOTO  2015       27101
# 5131  Mississippi  DE SOTO  2015      173271
# 5823      Florida  DE SOTO  2016       36255
# 6000    Louisiana  DE SOTO  2016       27190
# 6066  Mississippi  DE SOTO  2016      175721
# 6758      Florida  DE SOTO  2017       37241
# 6935    Louisiana  DE SOTO  2017       27267
# 7001  Mississippi  DE SOTO  2017      179005
# 7693      Florida  DE SOTO  2018       37368
# 7870    Louisiana  DE SOTO  2018       27426
# 7936  Mississippi  DE SOTO  2018      181932
# 8628      Florida  DE SOTO  2019       38001
# 8805    Louisiana  DE SOTO  2019       27463
# 8871  Mississippi  DE SOTO  2019      184945

# %%
# Replace 'DESOTO" with "DE SOTO"
ship["BUYER_COUNTY"].replace("DESOTO", "DE SOTO", inplace=True)
ship[ship["BUYER_COUNTY"] == "DE SOTO"]
# Out:
#      BUYER_STATE BUYER_COUNTY  YEAR/MONTH           MME  Year  FULL_STATES
# 84            FL      DE SOTO        2006   7179.580012  2006      Florida
# 85            FL      DE SOTO        2007   7726.090772  2007      Florida
# 86            FL      DE SOTO        2008   7953.604365  2008      Florida
# 87            FL      DE SOTO        2009   9826.920240  2009      Florida
# 88            FL      DE SOTO        2010  13087.621238  2010      Florida
# 89            FL      DE SOTO        2011  18280.029405  2011      Florida
# 90            FL      DE SOTO        2012  16695.973793  2012      Florida
# 566           LA      DE SOTO        2006   3884.347863  2006    Louisiana
# 567           LA      DE SOTO        2007   4720.608166  2007    Louisiana
# 568           LA      DE SOTO        2008   5600.356138  2008    Louisiana
# 569           LA      DE SOTO        2009   4751.077324  2009    Louisiana
# 570           LA      DE SOTO        2010   4627.306433  2010    Louisiana
# 571           LA      DE SOTO        2011   4950.024934  2011    Louisiana
# 572           LA      DE SOTO        2012   4935.913666  2012    Louisiana
# 1021          MS      DE SOTO        2006  32166.569342  2006  Mississippi
# 1022          MS      DE SOTO        2007  37094.065039  2007  Mississippi
# 1023          MS      DE SOTO        2008  42033.223000  2008  Mississippi
# 1024          MS      DE SOTO        2009  51782.135524  2009  Mississippi
# 1025          MS      DE SOTO        2010  53462.385451  2010  Mississippi
# 1026          MS      DE SOTO        2011  56970.969425  2011  Mississippi
# 1027          MS      DE SOTO        2012  61241.499844  2012  Mississippi

# %%
popc1.head()
# Out:
#      STNAME   CTYNAME  Year  Population
# 1  Arkansas  ARKANSAS  2000       20776
# 2  Arkansas    ASHLEY  2000       24179
# 3  Arkansas    BAXTER  2000       38446
# 4  Arkansas    BENTON  2000      154744
# 5  Arkansas     BOONE  2000       34051

# %%
popc2 = popc1[popc1.Year.isin([2006, 2007, 2008, 2009.2010, 2011, 2012])]

# %%
popc2.head()
# Out:
#         STNAME   CTYNAME  Year  Population
# 5611  Arkansas  ARKANSAS  2006       19785
# 5612  Arkansas    ASHLEY  2006       22501
# 5613  Arkansas    BAXTER  2006       40867
# 5614  Arkansas    BENTON  2006      195569
# 5615  Arkansas     BOONE  2006       36056

# %%
# Left Join Shipment & Population
merge = pd.merge(
    ship,
    popc1,
    how="left",
    left_on=["BUYER_COUNTY", "Year", "FULL_STATES"],
    right_on=["CTYNAME", "Year", "STNAME"],
)

# %%
merge.head()
# Out:
#   BUYER_STATE BUYER_COUNTY  YEAR/MONTH            MME  Year FULL_STATES  \
# 0          FL      ALACHUA        2006   82596.618688  2006     Florida
# 1          FL      ALACHUA        2007   95259.627977  2007     Florida
# 2          FL      ALACHUA        2008  114675.221922  2008     Florida
# 3          FL      ALACHUA        2009  141281.048185  2009     Florida
# 4          FL      ALACHUA        2010  150910.785876  2010     Florida
#
#     STNAME  CTYNAME  Population
# 0  Florida  ALACHUA      239506
# 1  Florida  ALACHUA      242685
# 2  Florida  ALACHUA      244888
# 3  Florida  ALACHUA      246657
# 4  Florida  ALACHUA      247336

# %%
# Look for null values
merge[merge["CTYNAME"].isnull()]
# Out:
# Empty DataFrame
# Columns: [BUYER_STATE, BUYER_COUNTY, YEAR/MONTH, MME, Year, FULL_STATES, STNAME, CTYNAME, Population]
# Index: []

# %%
# Drop duplicated Columns
merge = merge.drop(["CTYNAME", "STNAME"], axis=1)

# %%
merge.head()
# Out:
#   BUYER_STATE BUYER_COUNTY  YEAR/MONTH            MME  Year FULL_STATES  \
# 0          FL      ALACHUA        2006   82596.618688  2006     Florida
# 1          FL      ALACHUA        2007   95259.627977  2007     Florida
# 2          FL      ALACHUA        2008  114675.221922  2008     Florida
# 3          FL      ALACHUA        2009  141281.048185  2009     Florida
# 4          FL      ALACHUA        2010  150910.785876  2010     Florida
#
#    Population
# 0      239506
# 1      242685
# 2      244888
# 3      246657
# 4      247336

# %%
# Create a column call MME/CAP
merge["MME/CAP"] = round(merge["MME"] / merge["Population"], 4)
merge.head()
# Out:
#   BUYER_STATE BUYER_COUNTY  YEAR/MONTH            MME  Year FULL_STATES  \
# 0          FL      ALACHUA        2006   82596.618688  2006     Florida
# 1          FL      ALACHUA        2007   95259.627977  2007     Florida
# 2          FL      ALACHUA        2008  114675.221922  2008     Florida
# 3          FL      ALACHUA        2009  141281.048185  2009     Florida
# 4          FL      ALACHUA        2010  150910.785876  2010     Florida
#
#    Population  MME/CAP
# 0      239506   0.3449
# 1      242685   0.3925
# 2      244888   0.4683
# 3      246657   0.5728
# 4      247336   0.6101

# %%
# Group by state and county then count the number of values
merge["checker"] = merge.groupby(["BUYER_STATE", "BUYER_COUNTY"], as_index=False)[
    ["YEAR/MONTH"]
].transform("count")

# %%
merge.head()
# Out:
#   BUYER_STATE BUYER_COUNTY  YEAR/MONTH            MME  Year FULL_STATES  \
# 0          FL      ALACHUA        2006   82596.618688  2006     Florida
# 1          FL      ALACHUA        2007   95259.627977  2007     Florida
# 2          FL      ALACHUA        2008  114675.221922  2008     Florida
# 3          FL      ALACHUA        2009  141281.048185  2009     Florida
# 4          FL      ALACHUA        2010  150910.785876  2010     Florida
#
#    Population  MME/CAP  checker
# 0      239506   0.3449        7
# 1      242685   0.3925        7
# 2      244888   0.4683        7
# 3      246657   0.5728        7
# 4      247336   0.6101        7

# %%
# Dop unnecessary columns
merge1 = merge.drop(["Year", "MME", "Population"], axis=1)

# %%
# For FL, LA, MS, SC the count should be equal to 7
# Subset dataframe that has incomplete values
missing1 = merge1[
    (merge1["checker"] != 7) & (merge1.BUYER_STATE.isin(["FL", "LA", "MS", "SC"]))
]
missing1.shape
# Out:
# (6, 6)

# %%
missing1
# Out:
#     BUYER_STATE BUYER_COUNTY  YEAR/MONTH FULL_STATES  MME/CAP  checker
# 140          FL       GLADES        2009     Florida   0.2046        4
# 141          FL       GLADES        2010     Florida   0.5037        4
# 142          FL       GLADES        2011     Florida   0.3620        4
# 143          FL       GLADES        2012     Florida   0.1498        4
# 543          LA      CAMERON        2011   Louisiana   0.0003        2
# 544          LA      CAMERON        2012   Louisiana   0.0043        2

# %%
# Removed the 6 "incomplete" rows
merge_clean = merge1[
    ~((merge1["checker"] != 7) & (merge1.BUYER_STATE.isin(["FL", "LA", "MS", "SC"])))
]
merge_clean.shape
# Out:
# (53257, 6)

# %%
# For the rest of states the count should be equal to 84
# Subset dataframe that has incomplete values
missing2 = merge_clean[
    (merge_clean["checker"] != 84)
    & (~merge_clean.BUYER_STATE.isin(["FL", "LA", "MS", "SC"]))
]
missing2.shape
# Out:
# (1989, 6)

# %%
# Removed the 1989 "incomplete" rows
merge_clean2 = merge_clean[
    ~(
        (merge_clean["checker"] != 84)
        & (~merge_clean.BUYER_STATE.isin(["FL", "LA", "MS", "SC"]))
    )
]
merge_clean2.shape
# Out:
# (51268, 6)

# %%
missing1
# Out:
#     BUYER_STATE BUYER_COUNTY  YEAR/MONTH FULL_STATES  MME/CAP  checker
# 140          FL       GLADES        2009     Florida   0.2046        4
# 141          FL       GLADES        2010     Florida   0.5037        4
# 142          FL       GLADES        2011     Florida   0.3620        4
# 143          FL       GLADES        2012     Florida   0.1498        4
# 543          LA      CAMERON        2011   Louisiana   0.0003        2
# 544          LA      CAMERON        2012   Louisiana   0.0043        2

# %%
# Calculate the years that are not present
Complete = [2006, 2007, 2008, 2009, 2010, 2011, 2012]
Missing = {}
for i in missing1["BUYER_COUNTY"].unique():
    present = []
    for j in range(len(missing1.index)):
        if missing1.iloc[j, 1] == i:
            present.append(missing1.iloc[j, 2])
    mis = np.setdiff1d(Complete, present).tolist()
    Missing.update({i: mis})

# %%
# Check the accuracy
Missing
# Out:
# {'GLADES': [2006, 2007, 2008], 'CAMERON': [2006, 2007, 2008, 2009, 2010]}

# %%
# Create empty rows for the missing years
for key, value in Missing.items():
    for year in value:
        df = pd.DataFrame(
            [[np.nan, key, year, np.nan, 0, np.nan]],
            columns=[
                "BUYER_STATE",
                "BUYER_COUNTY",
                "YEAR/MONTH",
                "FULL_STATES",
                "MME/CAP",
                "checker",
            ],
        )
        missing1 = pd.concat([missing1, df], ignore_index=False)

# %%
missing1
# Out:
#     BUYER_STATE BUYER_COUNTY  YEAR/MONTH FULL_STATES  MME/CAP  checker
# 140          FL       GLADES        2009     Florida   0.2046      4.0
# 141          FL       GLADES        2010     Florida   0.5037      4.0
# 142          FL       GLADES        2011     Florida   0.3620      4.0
# 143          FL       GLADES        2012     Florida   0.1498      4.0
# 543          LA      CAMERON        2011   Louisiana   0.0003      2.0
# 544          LA      CAMERON        2012   Louisiana   0.0043      2.0
# 0           NaN       GLADES        2006         NaN   0.0000      NaN
# 0           NaN       GLADES        2007         NaN   0.0000      NaN
# 0           NaN       GLADES        2008         NaN   0.0000      NaN
# 0           NaN      CAMERON        2006         NaN   0.0000      NaN
# 0           NaN      CAMERON        2007         NaN   0.0000      NaN
# 0           NaN      CAMERON        2008         NaN   0.0000      NaN
# 0           NaN      CAMERON        2009         NaN   0.0000      NaN
# 0           NaN      CAMERON        2010         NaN   0.0000      NaN

# %%
# Fill Missing States
missing1["BUYER_STATE"] = missing1.groupby("BUYER_COUNTY")["BUYER_STATE"].transform(
    lambda v: v.fillna(method="ffill")
)

# %%
# Fill Missing Full States
missing1["FULL_STATES"] = missing1.groupby("BUYER_COUNTY")["FULL_STATES"].transform(
    lambda v: v.fillna(method="ffill")
)

# %%
# Fill Missing Full Checker
missing1["checker"] = missing1.groupby("BUYER_COUNTY")["checker"].transform(
    lambda v: v.fillna(method="ffill")
)

# %%
dates = []
for i in merge_clean[
    (merge_clean["BUYER_COUNTY"] == "ADAMS") & (merge_clean["BUYER_STATE"] == "WA")
]["YEAR/MONTH"]:
    dates.append(i)

# %%
dates
# Out:
# [20061,
#  20062,
#  20063,
#  20064,
#  20065,
#  20066,
#  20067,
#  20068,
#  20069,
#  20071,
#  20072,
#  20073,
#  20074,
#  20075,
#  20076,
#  20077,
#  20078,
#  20079,
#  20081,
#  20082,
#  20083,
#  20084,
#  20085,
#  20086,
#  20087,
#  20088,
#  20089,
#  20091,
#  20092,
#  20093,
#  20094,
#  20095,
#  20096,
#  20097,
#  20098,
#  20099,
#  20101,
#  20102,
#  20103,
#  20104,
#  20105,
#  20106,
#  20107,
#  20108,
#  20109,
#  20111,
#  20112,
#  20113,
#  20114,
#  20115,
#  20116,
#  20117,
#  20118,
#  20119,
#  20121,
#  20122,
#  20123,
#  20124,
#  20125,
#  20126,
#  20127,
#  20128,
#  20129,
#  200610,
#  200611,
#  200612,
#  200710,
#  200711,
#  200712,
#  200810,
#  200811,
#  200812,
#  200910,
#  200911,
#  200912,
#  201010,
#  201011,
#  201012,
#  201110,
#  201111,
#  201112,
#  201210,
#  201211,
#  201212]

# %%
missing2.head()
# Out:
#      BUYER_STATE BUYER_COUNTY  YEAR/MONTH FULL_STATES  MME/CAP  checker
# 2806          AR    CLEVELAND       20061    Arkansas   0.0012       34
# 2807          AR    CLEVELAND       20062    Arkansas   0.0015       34
# 2808          AR    CLEVELAND       20063    Arkansas   0.0014       34
# 2809          AR    CLEVELAND       20064    Arkansas   0.0004       34
# 2810          AR    CLEVELAND       20065    Arkansas   0.0012       34

# %%
# Calculate the months that are not present
Complete2 = dates
Missing2 = {}
for i in missing2["BUYER_COUNTY"].unique():
    present = []
    for j in range(len(missing2.index)):
        if missing2.iloc[j, 1] == i:
            present.append(missing2.iloc[j, 2])
    mis = np.setdiff1d(Complete2, present).tolist()
    Missing2.update({i: mis})

# %%
Missing2
# Out:
# {'CLEVELAND': [20091,
#   20092,
#   20093,
#   20094,
#   20095,
#   20096,
#   20097,
#   20098,
#   20099,
#   20101,
#   20102,
#   20103,
#   20104,
#   20105,
#   20106,
#   20107,
#   20108,
#   20109,
#   20111,
#   20112,
#   20113,
#   20114,
#   20115,
#   20116,
#   20117,
#   20118,
#   20119,
#   20121,
#   20122,
#   20123,
#   20124,
#   20125,
#   20126,
#   20127,
#   20128,
#   20129,
#   200811,
#   200812,
#   200910,
#   200911,
#   200912,
#   201010,
#   201011,
#   201012,
#   201110,
#   201111,
#   201112,
#   201210,
#   201211,
#   201212],
#  'KIOWA': [20076,
#   20077,
#   20078,
#   20079,
#   20081,
#   20082,
#   20083,
#   20084,
#   20085,
#   20086,
#   20087,
#   20088,
#   20089,
#   20091,
#   20092,
#   20093,
#   20094,
#   20095,
#   20096,
#   20097,
#   20098,
#   20099,
#   20101,
#   20102,
#   20103,
#   20104,
#   20105,
#   20106,
#   20107,
#   20108,
#   20109,
#   20111,
#   20112,
#   20113,
#   20114,
#   20115,
#   20116,
#   20117,
#   20118,
#   20119,
#   200710,
#   200711,
#   200712,
#   200810,
#   200811,
#   200812,
#   200910,
#   200911,
#   200912,
#   201010,
#   201011,
#   201012,
#   201110,
#   201112],
#  'LANE': [20127, 20128, 20129, 201210, 201211, 201212],
#  'LOGAN': [20061, 20062, 20063, 20064, 20065, 20066],
#  'RUSH': [20082, 20083, 20084, 20085, 20086, 20087, 20088],
#  'WABAUNSEE': [20061,
#   20062,
#   20063,
#   20064,
#   20065,
#   20066,
#   20067,
#   20068,
#   20069,
#   20071,
#   20072,
#   20073,
#   20074,
#   20075,
#   20076,
#   20077,
#   20078,
#   20079,
#   20081,
#   20082,
#   20083,
#   20084,
#   20085,
#   20086,
#   20087,
#   20088,
#   20089,
#   20091,
#   20092,
#   20093,
#   20094,
#   20095,
#   20096,
#   20097,
#   20098,
#   20099,
#   20101,
#   20102,
#   20103,
#   20104,
#   20105,
#   20106,
#   20107,
#   20108,
#   20109,
#   20111,
#   20112,
#   20113,
#   20114,
#   20115,
#   20116,
#   20117,
#   20118,
#   20121,
#   20123,
#   20124,
#   20125,
#   20127,
#   20128,
#   20129,
#   200610,
#   200611,
#   200612,
#   200710,
#   200711,
#   200712,
#   200810,
#   200811,
#   200812,
#   200910,
#   200911,
#   200912,
#   201010,
#   201011,
#   201012,
#   201110,
#   201111,
#   201112,
#   201210,
#   201211,
#   201212],
#  'WALLACE': [20061,
#   20062,
#   20063,
#   20064,
#   20065,
#   20066,
#   20067,
#   20068,
#   20069,
#   20071,
#   20072,
#   20073,
#   20074,
#   20075,
#   20076,
#   20077,
#   20078,
#   20079,
#   20081,
#   20082,
#   20083,
#   20084,
#   20085,
#   20086,
#   20087,
#   20088,
#   20089,
#   20091,
#   20092,
#   20093,
#   20094,
#   20095,
#   20096,
#   20097,
#   20098,
#   20099,
#   20101,
#   20102,
#   20103,
#   20104,
#   20105,
#   20106,
#   20107,
#   20108,
#   20109,
#   20111,
#   20112,
#   20113,
#   20114,
#   20115,
#   20116,
#   20117,
#   20118,
#   20119,
#   20121,
#   20122,
#   200610,
#   200611,
#   200612,
#   200710,
#   200711,
#   200712,
#   200810,
#   200811,
#   200812,
#   200910,
#   200911,
#   200912,
#   201010,
#   201011,
#   201012,
#   201110,
#   201111,
#   201112],
#  'CATRON': [20061,
#   20062,
#   20063,
#   20064,
#   20065,
#   20066,
#   20067,
#   20068,
#   20069,
#   20071,
#   20072,
#   20073,
#   20074,
#   20075,
#   20076,
#   20077,
#   20078,
#   20079,
#   20081,
#   20082,
#   20083,
#   20084,
#   20085,
#   20086,
#   20087,
#   20088,
#   20089,
#   20091,
#   20092,
#   20093,
#   20094,
#   20096,
#   20097,
#   20098,
#   20099,
#   20101,
#   20102,
#   20103,
#   20104,
#   20105,
#   20106,
#   20107,
#   20108,
#   20109,
#   20111,
#   20112,
#   20113,
#   20114,
#   20115,
#   20116,
#   20117,
#   20118,
#   20119,
#   20121,
#   20122,
#   20123,
#   20124,
#   20125,
#   20126,
#   20127,
#   20128,
#   20129,
#   200610,
#   200611,
#   200612,
#   200710,
#   200711,
#   200712,
#   200811,
#   200812,
#   200910,
#   200911,
#   200912,
#   201010,
#   201011,
#   201012,
#   201110,
#   201111,
#   201112,
#   201210,
#   201211,
#   201212],
#  'HIDALGO': [20085,
#   20086,
#   20087,
#   20088,
#   20089,
#   20091,
#   20092,
#   20093,
#   20094,
#   20095,
#   20096,
#   20097,
#   20098,
#   20099,
#   20101,
#   20102,
#   20103,
#   20104,
#   20105,
#   20106,
#   20107,
#   20108,
#   20109,
#   20111,
#   20112,
#   20113,
#   20114,
#   20115,
#   20116,
#   20117,
#   20118,
#   20119,
#   20121,
#   20122,
#   20123,
#   20124,
#   20125,
#   20126,
#   20127,
#   20128,
#   20129,
#   200810,
#   200811,
#   200812,
#   200910,
#   200911,
#   200912,
#   201010,
#   201011,
#   201012,
#   201110,
#   201111,
#   201112,
#   201210,
#   201211,
#   201212],
#  'ARCHER': [20061,
#   20062,
#   20063,
#   20064,
#   20065,
#   20066,
#   20067,
#   20068,
#   20069,
#   20071,
#   20072,
#   20074,
#   20075,
#   20077,
#   20078,
#   20079,
#   20081,
#   20082,
#   20083,
#   20084,
#   20085,
#   20086,
#   20087,
#   20088,
#   20089,
#   20091,
#   20092,
#   20093,
#   20094,
#   20095,
#   20096,
#   20097,
#   20098,
#   20099,
#   20101,
#   20102,
#   20103,
#   20104,
#   20105,
#   20106,
#   20107,
#   20108,
#   20109,
#   20111,
#   20112,
#   20113,
#   20114,
#   20115,
#   20116,
#   20117,
#   20118,
#   20119,
#   20121,
#   20122,
#   20123,
#   20124,
#   20125,
#   20126,
#   20127,
#   20128,
#   200610,
#   200611,
#   200612,
#   200710,
#   200711,
#   200712,
#   200810,
#   200811,
#   200812,
#   200910,
#   200911,
#   200912,
#   201010,
#   201011,
#   201012,
#   201110,
#   201111,
#   201112,
#   201210,
#   201211,
#   201212],
#  'ARMSTRONG': [20061, 20065],
#  'CALLAHAN': [20061],
#  'COCHRAN': [20061,
#   20065,
#   20071,
#   20072,
#   20073,
#   20074,
#   20075,
#   20076,
#   20077,
#   20078,
#   20079,
#   20081,
#   20082,
#   20083,
#   20084,
#   20085,
#   20086,
#   20087,
#   20088,
#   20089,
#   20091,
#   20092,
#   20093,
#   20094,
#   20095,
#   20096,
#   20097,
#   20098,
#   20099,
#   20101,
#   20102,
#   20103,
#   20104,
#   20105,
#   20106,
#   20107,
#   20108,
#   20109,
#   20111,
#   20112,
#   20113,
#   20114,
#   20115,
#   20116,
#   20117,
#   20118,
#   20119,
#   20121,
#   20122,
#   20123,
#   20124,
#   20125,
#   20126,
#   20127,
#   20128,
#   20129,
#   200612,
#   200710,
#   200711,
#   200712,
#   200810,
#   200811,
#   200812,
#   200910,
#   200911,
#   200912,
#   201010,
#   201011,
#   201012,
#   201110,
#   201111,
#   201112,
#   201210,
#   201211,
#   201212],
#  'COLEMAN': [201012],
#  'CONCHO': [20061,
#   20062,
#   20063,
#   20064,
#   20065,
#   20066,
#   20067,
#   20068,
#   20069,
#   20071,
#   20074,
#   20077,
#   20078,
#   20079,
#   20081,
#   20082,
#   20083,
#   20084,
#   20085,
#   20086,
#   20087,
#   20088,
#   20089,
#   20091,
#   20092,
#   20093,
#   20094,
#   20095,
#   20096,
#   20097,
#   20098,
#   20099,
#   20101,
#   20102,
#   20103,
#   20104,
#   20105,
#   20106,
#   20107,
#   20108,
#   20109,
#   20111,
#   20112,
#   20113,
#   20114,
#   20115,
#   20116,
#   20117,
#   20118,
#   20119,
#   20121,
#   20122,
#   20123,
#   200610,
#   200611,
#   200612,
#   200711,
#   200712,
#   200810,
#   200811,
#   200812,
#   200910,
#   200911,
#   200912,
#   201010,
#   201011,
#   201012,
#   201110,
#   201111,
#   201112],
#  'CULBERSON': [20062,
#   20063,
#   20064,
#   20065,
#   20066,
#   20067,
#   20068,
#   20069,
#   20071,
#   20072,
#   20073,
#   20074,
#   20075,
#   20076,
#   20077,
#   20078,
#   20079,
#   20081,
#   20082,
#   20083,
#   20084,
#   20085,
#   20086,
#   20087,
#   20088,
#   20089,
#   20091,
#   20092,
#   20093,
#   20094,
#   20095,
#   20096,
#   20097,
#   20098,
#   20099,
#   20101,
#   20102,
#   20103,
#   20104,
#   20105,
#   20106,
#   20107,
#   20108,
#   20109,
#   20111,
#   20112,
#   20113,
#   20114,
#   20115,
#   20116,
#   20117,
#   20118,
#   20119,
#   20121,
#   20122,
#   20123,
#   20124,
#   20125,
#   20126,
#   20127,
#   20128,
#   20129,
#   200610,
#   200611,
#   200612,
#   200710,
#   200711,
#   200712,
#   200810,
#   200811,
#   200812,
#   200910,
#   200911,
#   200912,
#   201010,
#   201011,
#   201012,
#   201110,
#   201111,
#   201112,
#   201210,
#   201211,
#   201212],
#  'DELTA': [20079,
#   20081,
#   20082,
#   20083,
#   20084,
#   20085,
#   20086,
#   20087,
#   20088,
#   20089,
#   20091,
#   20092,
#   20093,
#   20094,
#   20095,
#   20096,
#   20097,
#   20098,
#   20099,
#   20101,
#   20102,
#   20103,
#   20104,
#   20105,
#   20106,
#   20107,
#   20108,
#   20109,
#   200710,
#   200711,
#   200712,
#   200810,
#   200811,
#   200812,
#   200910,
#   200911,
#   200912],
#  'EDWARDS': [20061,
#   20062,
#   20063,
#   20064,
#   20066,
#   20067,
#   20068,
#   20069,
#   20071,
#   20072,
#   20073,
#   20074,
#   20075,
#   20076,
#   20077,
#   20078,
#   20079,
#   20081,
#   20083,
#   20084,
#   20085,
#   20087,
#   20088,
#   20089,
#   20091,
#   20093,
#   20095,
#   20097,
#   20098,
#   20099,
#   20101,
#   20102,
#   20104,
#   20105,
#   20107,
#   20108,
#   20112,
#   20113,
#   20114,
#   20115,
#   20116,
#   20117,
#   20118,
#   20119,
#   20121,
#   20122,
#   20123,
#   20124,
#   20125,
#   20126,
#   20127,
#   20128,
#   200611,
#   200612,
#   200710,
#   200711,
#   200812,
#   200910,
#   201010,
#   201011,
#   201110,
#   201111,
#   201112,
#   201210,
#   201211,
#   201212],
#  'GARZA': [201012],
#  'KINNEY': [201012],
#  'KNOX': [20123, 20124, 20125, 20126, 201012],
#  'LAMB': [20065],
#  'LIPSCOMB': [20061,
#   20065,
#   20071,
#   20072,
#   20073,
#   20074,
#   20075,
#   20076,
#   20077,
#   20078,
#   20079,
#   20081,
#   20082,
#   20083,
#   20084,
#   20085,
#   20086,
#   20087,
#   20088,
#   20089,
#   20091,
#   20092,
#   20093,
#   20094,
#   20095,
#   20096,
#   20097,
#   20098,
#   20099,
#   20101,
#   20102,
#   20103,
#   20104,
#   20105,
#   20106,
#   20107,
#   20108,
#   20109,
#   20111,
#   20112,
#   20113,
#   20114,
#   20115,
#   20116,
#   20117,
#   20118,
#   20119,
#   20121,
#   20122,
#   20123,
#   20124,
#   20125,
#   20126,
#   20127,
#   20128,
#   20129,
#   200610,
#   200611,
#   200612,
#   200710,
#   200711,
#   200712,
#   200810,
#   200811,
#   200812,
#   200910,
#   200911,
#   200912,
#   201010,
#   201011,
#   201012,
#   201110,
#   201111,
#   201112,
#   201210,
#   201211,
#   201212],
#  'LYNN': [201012],
#  'MARTIN': [201012],
#  'MASON': [201012],
#  'MENARD': [20064],
#  'OLDHAM': [20061,
#   20062,
#   20063,
#   20064,
#   20065,
#   20066,
#   20067,
#   20068,
#   20069,
#   20071,
#   20072,
#   20073,
#   20074,
#   20075,
#   20076,
#   20077,
#   20078,
#   20079,
#   20081,
#   20082,
#   20083,
#   20084,
#   20085,
#   20086,
#   20087,
#   20088,
#   20089,
#   20091,
#   20092,
#   20093,
#   20094,
#   20095,
#   20096,
#   20097,
#   20098,
#   20099,
#   20101,
#   20102,
#   20103,
#   20104,
#   20105,
#   20106,
#   20107,
#   20108,
#   20109,
#   20111,
#   20112,
#   20113,
#   20114,
#   20115,
#   20116,
#   20117,
#   20118,
#   20119,
#   20121,
#   20123,
#   20124,
#   20125,
#   20126,
#   20127,
#   20128,
#   20129,
#   200610,
#   200611,
#   200612,
#   200710,
#   200711,
#   200712,
#   200810,
#   200811,
#   200812,
#   200910,
#   200911,
#   200912,
#   201010,
#   201011,
#   201012,
#   201110,
#   201210,
#   201211,
#   201212],
#  'PRESIDIO': [20061,
#   20062,
#   20065,
#   20066,
#   20067,
#   20068,
#   20069,
#   20071,
#   20072,
#   20073,
#   20074,
#   20075,
#   20076,
#   20077,
#   20078,
#   20079,
#   20081,
#   20082,
#   20083,
#   20084,
#   20085,
#   20086,
#   20087,
#   20088,
#   20089,
#   20091,
#   20092,
#   20093,
#   20094,
#   20095,
#   20096,
#   20097,
#   20098,
#   20099,
#   20101,
#   20102,
#   20103,
#   20104,
#   20105,
#   20106,
#   20107,
#   20108,
#   20109,
#   20111,
#   20112,
#   20113,
#   20114,
#   20115,
#   20116,
#   20117,
#   20118,
#   20119,
#   20121,
#   20122,
#   20123,
#   20124,
#   20125,
#   20126,
#   20127,
#   20128,
#   20129,
#   200610,
#   200611,
#   200612,
#   200710,
#   200711,
#   200712,
#   200810,
#   200811,
#   200812,
#   200910,
#   200911,
#   200912,
#   201010,
#   201011,
#   201012,
#   201110,
#   201111,
#   201112,
#   201210,
#   201211,
#   201212],
#  'REAGAN': [20065,
#   20101,
#   20102,
#   20103,
#   20104,
#   20105,
#   20106,
#   20107,
#   20108,
#   20109,
#   20111,
#   20112,
#   20113,
#   20114,
#   20115,
#   20116,
#   20117,
#   20118,
#   20119,
#   20121,
#   20122,
#   20123,
#   20124,
#   20125,
#   20126,
#   20127,
#   20128,
#   20129,
#   201010,
#   201011,
#   201012,
#   201110,
#   201111,
#   201112,
#   201210,
#   201211,
#   201212],
#  'REAL': [20061,
#   20062,
#   20063,
#   20064,
#   20065,
#   20067,
#   20068,
#   20069,
#   20071,
#   20072,
#   20073,
#   20074,
#   20075,
#   20076,
#   20077,
#   20078,
#   20079,
#   20081,
#   20082,
#   20083,
#   20084,
#   20085,
#   20086,
#   20087,
#   20088,
#   20089,
#   20091,
#   20092,
#   20093,
#   20094,
#   20095,
#   20096,
#   20097,
#   20098,
#   20099,
#   20101,
#   20102,
#   20103,
#   20104,
#   20105,
#   20106,
#   20107,
#   20108,
#   20109,
#   20111,
#   20112,
#   20113,
#   20114,
#   20115,
#   20116,
#   20117,
#   20118,
#   20119,
#   20121,
#   20122,
#   20123,
#   20124,
#   20125,
#   20126,
#   20127,
#   20128,
#   20129,
#   200610,
#   200611,
#   200612,
#   200710,
#   200711,
#   200712,
#   200810,
#   200811,
#   200812,
#   200910,
#   200911,
#   200912,
#   201010,
#   201011,
#   201110,
#   201111,
#   201112,
#   201210,
#   201211,
#   201212],
#  'SCHLEICHER': [20061,
#   20062,
#   20063,
#   20064,
#   20065,
#   20066,
#   20067,
#   20068,
#   20069,
#   20071,
#   20072,
#   20073,
#   20074,
#   20075,
#   20076,
#   20077,
#   20078,
#   20079,
#   20081,
#   20082,
#   20083,
#   20084,
#   20085,
#   20086,
#   20087,
#   20088,
#   20089,
#   20091,
#   20092,
#   20093,
#   20094,
#   20095,
#   20096,
#   20097,
#   20098,
#   20099,
#   20101,
#   20102,
#   20103,
#   20104,
#   20105,
#   20106,
#   20107,
#   20108,
#   20109,
#   20111,
#   20112,
#   20113,
#   20114,
#   20115,
#   20116,
#   20117,
#   20118,
#   20119,
#   20121,
#   20122,
#   20123,
#   20124,
#   20125,
#   20126,
#   20127,
#   20128,
#   200610,
#   200611,
#   200612,
#   200710,
#   200711,
#   200712,
#   200810,
#   200811,
#   200812,
#   200910,
#   200911,
#   200912,
#   201010,
#   201011,
#   201012,
#   201110,
#   201111,
#   201112,
#   201210,
#   201211,
#   201212],
#  'SHACKELFORD': [20091,
#   20092,
#   20093,
#   20094,
#   20095,
#   20096,
#   20097,
#   20098,
#   20099,
#   200810,
#   200811,
#   200812,
#   200910,
#   200911],
#  'SHERMAN': [20061, 20065],
#  'STERLING': [20061,
#   20062,
#   20063,
#   20064,
#   20065,
#   20066,
#   20067,
#   20068,
#   20069,
#   20071,
#   20072,
#   20073,
#   20074,
#   20075,
#   20076,
#   20077,
#   20078,
#   20079,
#   20081,
#   20082,
#   20083,
#   20084,
#   20085,
#   20086,
#   20087,
#   20088,
#   20089,
#   20091,
#   20092,
#   20093,
#   20094,
#   20095,
#   20097,
#   20098,
#   20099,
#   20101,
#   20102,
#   20103,
#   20104,
#   20105,
#   20106,
#   20107,
#   20108,
#   20109,
#   20111,
#   20112,
#   20113,
#   20114,
#   20115,
#   20116,
#   20117,
#   20118,
#   20119,
#   20121,
#   20122,
#   20123,
#   20124,
#   20125,
#   20126,
#   20127,
#   20128,
#   20129,
#   200610,
#   200611,
#   200612,
#   200710,
#   200711,
#   200712,
#   200810,
#   200811,
#   200812,
#   200910,
#   200911,
#   200912,
#   201010,
#   201011,
#   201012,
#   201110,
#   201111,
#   201112,
#   201210,
#   201211,
#   201212],
#  'THROCKMORTON': [20061,
#   20062,
#   20063,
#   20064,
#   20065,
#   20066,
#   20067,
#   20068,
#   20069,
#   20071,
#   20073,
#   20074,
#   20075,
#   20076,
#   20077,
#   20078,
#   20079,
#   20081,
#   20082,
#   20083,
#   20084,
#   20085,
#   20086,
#   20087,
#   20088,
#   20089,
#   20091,
#   20092,
#   20093,
#   20094,
#   20096,
#   20097,
#   20098,
#   20099,
#   20101,
#   20102,
#   20103,
#   20104,
#   20105,
#   20106,
#   20107,
#   20108,
#   20109,
#   20111,
#   20112,
#   20113,
#   20114,
#   20115,
#   20117,
#   20118,
#   20119,
#   20121,
#   20122,
#   20123,
#   20124,
#   20125,
#   20126,
#   20127,
#   20128,
#   20129,
#   200610,
#   200611,
#   200612,
#   200710,
#   200711,
#   200712,
#   200810,
#   200811,
#   200812,
#   200910,
#   200911,
#   200912,
#   201010,
#   201011,
#   201012,
#   201110,
#   201111,
#   201112,
#   201211,
#   201212],
#  'UPTON': [20061,
#   20062,
#   20063,
#   20064,
#   20065,
#   20066,
#   20067,
#   20068,
#   20069,
#   20071,
#   20072,
#   20073,
#   20074,
#   20075,
#   20076,
#   20077,
#   20078,
#   20079,
#   20081,
#   20082,
#   20083,
#   20084,
#   20085,
#   20086,
#   20087,
#   20088,
#   20089,
#   20091,
#   20092,
#   20093,
#   20094,
#   20095,
#   20096,
#   20097,
#   20098,
#   20099,
#   200610,
#   200611,
#   200612,
#   200710,
#   200711,
#   200712,
#   200810,
#   200811,
#   200812,
#   200910,
#   200911,
#   200912],
#  'ALPINE': [20061,
#   20062,
#   20063,
#   20064,
#   20065,
#   20066,
#   20068,
#   20069,
#   20071,
#   20072,
#   20073,
#   20074,
#   20075,
#   20076,
#   20077,
#   20078,
#   20079,
#   20081,
#   20082,
#   20083,
#   20084,
#   20085,
#   20086,
#   20087,
#   20088,
#   20089,
#   20094,
#   20095,
#   20096,
#   20097,
#   20098,
#   20099,
#   20102,
#   20104,
#   20105,
#   20106,
#   20107,
#   20108,
#   20109,
#   20111,
#   20112,
#   20113,
#   20114,
#   20115,
#   20116,
#   20117,
#   20118,
#   20119,
#   20121,
#   20123,
#   20124,
#   20125,
#   20126,
#   20127,
#   20128,
#   20129,
#   200610,
#   200611,
#   200612,
#   200710,
#   200711,
#   200712,
#   200810,
#   200811,
#   200910,
#   200911,
#   201010,
#   201012,
#   201110,
#   201111,
#   201210,
#   201211,
#   201212],
#  'CUSTER': [20061,
#   20062,
#   20063,
#   20064,
#   20065,
#   20066,
#   20067,
#   20071,
#   20072,
#   20074,
#   20077,
#   20079,
#   20081,
#   20082,
#   20083,
#   20084,
#   20085,
#   20086,
#   20087,
#   20088,
#   20089,
#   20091,
#   20092,
#   20093,
#   20094,
#   20095,
#   20096,
#   20097,
#   20098,
#   20099,
#   20103,
#   20104,
#   20105,
#   20106,
#   20108,
#   20109,
#   20112,
#   20115,
#   20118,
#   20127,
#   200612,
#   200710,
#   200711,
#   200712,
#   200810,
#   200811,
#   200812,
#   200910,
#   200912,
#   201010,
#   201012,
#   201111,
#   201210],
#  'GILPIN': [20088, 201212],
#  'HINSDALE': [20061,
#   20062,
#   20063,
#   20064,
#   20065,
#   20066,
#   20071,
#   20072,
#   20074,
#   20075,
#   20076,
#   20079,
#   20083,
#   20085,
#   20086,
#   20092,
#   20093,
#   20094,
#   20096,
#   20098,
#   20101,
#   20102,
#   20103,
#   20104,
#   20105,
#   20106,
#   20109,
#   20111,
#   20113,
#   20114,
#   20115,
#   20116,
#   20118,
#   20121,
#   20122,
#   20123,
#   20124,
#   20125,
#   20126,
#   20129,
#   200610,
#   200611,
#   200612,
#   200710,
#   200711,
#   200712,
#   200810,
#   200811,
#   200812,
#   200910,
#   200911,
#   200912,
#   201010,
#   201011,
#   201012,
#   201110,
#   201111,
#   201112,
#   201211,
#   201212],
#  'MINERAL': [20061,
#   20062,
#   20063,
#   20064,
#   20065,
#   20066,
#   20067,
#   20068,
#   20069,
#   20071,
#   20072,
#   20073,
#   20074,
#   20075,
#   20076,
#   20077,
#   20078,
#   20079,
#   20081,
#   20082,
#   20083,
#   20084,
#   20085,
#   20086,
#   20087,
#   20088,
#   20089,
#   20091,
#   20092,
#   20093,
#   20094,
#   20095,
#   20096,
#   20097,
#   20098,
#   20099,
#   20101,
#   20102,
#   20103,
#   20104,
#   20105,
#   20106,
#   20107,
#   20108,
#   20111,
#   20112,
#   20113,
#   20114,
#   20115,
#   20116,
#   20117,
#   20118,
#   20119,
#   20121,
#   20122,
#   20123,
#   20124,
#   20125,
#   20126,
#   20127,
#   20128,
#   20129,
#   200610,
#   200611,
#   200612,
#   200710,
#   200711,
#   200712,
#   200810,
#   200811,
#   200812,
#   200910,
#   200911,
#   200912,
#   201010,
#   201011,
#   201012,
#   201110,
#   201111,
#   201112,
#   201210,
#   201211,
#   201212],
#  'PHILLIPS': [20128],
#  'RIO BLANCO': [20096, 20097, 20099, 200910],
#  'SAGUACHE': [20061,
#   20063,
#   20064,
#   20065,
#   20067,
#   20069,
#   20072,
#   20073,
#   20074,
#   20075,
#   20076,
#   20077,
#   20078,
#   20079,
#   20081,
#   20082,
#   20083,
#   20084,
#   20085,
#   20086,
#   20087,
#   20088,
#   20094,
#   20095,
#   20101,
#   20105,
#   20107,
#   20108,
#   20109,
#   20111,
#   20112,
#   20114,
#   20115,
#   20116,
#   20117,
#   20118,
#   20119,
#   20121,
#   20122,
#   20123,
#   20124,
#   20125,
#   20126,
#   20129,
#   200610,
#   200710,
#   200711,
#   200712,
#   200810,
#   200811,
#   200812,
#   200910,
#   200912,
#   201010,
#   201011,
#   201012,
#   201110,
#   201111,
#   201112,
#   201211,
#   201212],
#  'SAN JUAN': [20061,
#   20062,
#   20063,
#   20064,
#   20065,
#   20066,
#   20068,
#   20069,
#   20071,
#   20072,
#   20073,
#   20074,
#   20075,
#   20076,
#   20077,
#   20078,
#   20079,
#   20081,
#   20082,
#   20083,
#   20084,
#   20085,
#   20086,
#   20087,
#   20088,
#   20089,
#   20091,
#   20092,
#   20093,
#   20094,
#   20095,
#   20096,
#   20097,
#   20098,
#   20099,
#   20101,
#   20102,
#   20103,
#   20104,
#   20105,
#   20106,
#   20107,
#   20108,
#   20109,
#   20111,
#   20112,
#   20113,
#   20114,
#   20115,
#   20116,
#   20117,
#   20118,
#   20119,
#   20121,
#   20122,
#   20123,
#   20124,
#   20125,
#   20126,
#   20127,
#   20128,
#   20129,
#   200610,
#   200611,
#   200612,
#   200710,
#   200711,
#   200712,
#   200810,
#   200811,
#   200812,
#   200910,
#   200911,
#   200912,
#   201010,
#   201011,
#   201012,
#   201110,
#   201111,
#   201112,
#   201210,
#   201211,
#   201212],
#  'WASHINGTON': [20091,
#   20092,
#   20093,
#   20094,
#   20095,
#   20096,
#   20097,
#   20098,
#   20099,
#   20101,
#   20102,
#   20103,
#   20104,
#   20105,
#   20106,
#   20107,
#   20108,
#   20109,
#   20111,
#   20112,
#   20113,
#   20114,
#   20115,
#   20116,
#   20117,
#   20118,
#   20119,
#   20121,
#   20122,
#   20123,
#   20124,
#   20125,
#   20126,
#   20127,
#   20128,
#   20129,
#   200812,
#   200910,
#   200911,
#   200912,
#   201010,
#   201011,
#   201012,
#   201110,
#   201111,
#   201112,
#   201210,
#   201211,
#   201212],
#  'WHEELER': [20061,
#   20062,
#   20063,
#   20064,
#   20065,
#   20066,
#   20067,
#   20068,
#   20069,
#   20071,
#   20072,
#   20073,
#   20074,
#   20075,
#   20076,
#   20077,
#   20078,
#   20079,
#   20081,
#   20082,
#   20083,
#   20084,
#   20085,
#   20086,
#   20087,
#   20088,
#   20089,
#   20092,
#   20097,
#   20103,
#   20107,
#   20109,
#   20113,
#   20118,
#   20119,
#   20122,
#   20123,
#   20124,
#   20125,
#   20127,
#   20128,
#   20129,
#   200610,
#   200611,
#   200612,
#   200710,
#   200711,
#   200712,
#   200810,
#   200811,
#   200812,
#   200911,
#   200912,
#   201010,
#   201011,
#   201012,
#   201110,
#   201111,
#   201112,
#   201211,
#   201212]}

# %%
# Create empty rows for the missing months
for key, value in Missing2.items():
    for year in value:
        df = pd.DataFrame(
            [[np.nan, key, year, np.nan, 0, np.nan]],
            columns=[
                "BUYER_STATE",
                "BUYER_COUNTY",
                "YEAR/MONTH",
                "FULL_STATES",
                "MME/CAP",
                "checker",
            ],
        )
        missing2 = pd.concat([missing2, df], ignore_index=False)

# %%
# Fill Missing States
missing2["BUYER_STATE"] = missing2.groupby("BUYER_COUNTY")["BUYER_STATE"].transform(
    lambda v: v.fillna(method="ffill")
)

# %%
# Fill Missing Full States
missing2["FULL_STATES"] = missing2.groupby("BUYER_COUNTY")["FULL_STATES"].transform(
    lambda v: v.fillna(method="ffill")
)

# %%
# Fill Missing Checker
missing2["checker"] = missing2.groupby("BUYER_COUNTY")["checker"].transform(
    lambda v: v.fillna(method="ffill")
)

# %%
missing2.tail()
# Out:
#   BUYER_STATE BUYER_COUNTY  YEAR/MONTH FULL_STATES  MME/CAP  checker
# 0          OR      WHEELER      201110      Oregon      0.0     23.0
# 0          OR      WHEELER      201111      Oregon      0.0     23.0
# 0          OR      WHEELER      201112      Oregon      0.0     23.0
# 0          OR      WHEELER      201211      Oregon      0.0     23.0
# 0          OR      WHEELER      201212      Oregon      0.0     23.0

# %%
# Concatenate all dataframes together
merge_final = pd.concat([merge_clean2, missing1], ignore_index=False)
merge_final = pd.concat([merge_final, missing2], ignore_index=False)

# %%
# Group by state and county then count the number of values again
merge_final["final_checker"] = merge_final.groupby(
    ["BUYER_STATE", "BUYER_COUNTY"], as_index=False
)[["YEAR/MONTH"]].transform("count")

# %%
# Check if there are any missing rows again
merge_final[
    (merge_final["final_checker"] != 7)
    & (merge_final.BUYER_STATE.isin(["FL", "LA", "MS", "SC"]))
]
# Out:
# Empty DataFrame
# Columns: [BUYER_STATE, BUYER_COUNTY, YEAR/MONTH, FULL_STATES, MME/CAP, checker, final_checker]
# Index: []

# %%
# For the rest of states the count should be equal to 84
# Subset dataframe that has incomplete values
merge_final[
    (merge_final["final_checker"] != 84)
    & (~merge_final.BUYER_STATE.isin(["FL", "LA", "MS", "SC"]))
]
# Out:
# Empty DataFrame
# Columns: [BUYER_STATE, BUYER_COUNTY, YEAR/MONTH, FULL_STATES, MME/CAP, checker, final_checker]
# Index: []

# %%
# Create a column call "PolicyState"
merge_final["PolicyState"] = (
    (merge_final["BUYER_STATE"] == "FL")
    | ((merge_final["BUYER_STATE"] == "TX"))
    | (merge_final["BUYER_STATE"] == "WA")
)

# %%
# Create a column call Post
merge_final["Post"] = (
    (
        (
            (merge["BUYER_STATE"] == "FL")
            | (merge["BUYER_STATE"] == "LA")
            | (merge["BUYER_STATE"] == "MS")
            | (merge["BUYER_STATE"] == "SC")
        )
        & (merge["Year"] >= 2010)
    )
    | (
        (
            (merge["BUYER_STATE"] == "TX")
            | (merge["BUYER_STATE"] == "AR")
            | (merge["BUYER_STATE"] == "NM")
            | (merge["BUYER_STATE"] == "KS")
        )
        & (merge["Year"] >= 2007)
    )
    | (
        (
            (merge["BUYER_STATE"] == "WA")
            | (merge["BUYER_STATE"] == "OR")
            | (merge["BUYER_STATE"] == "CO")
            | (merge["BUYER_STATE"] == "CA")
        )
        & (merge["Year"] >= 2012)
    )
)

# %%
merge_final.head()
# Out:
#   BUYER_STATE BUYER_COUNTY  YEAR/MONTH FULL_STATES  MME/CAP  checker  \
# 0          FL      ALACHUA        2006     Florida   0.3449      7.0
# 1          FL      ALACHUA        2007     Florida   0.3925      7.0
# 2          FL      ALACHUA        2008     Florida   0.4683      7.0
# 3          FL      ALACHUA        2009     Florida   0.5728      7.0
# 4          FL      ALACHUA        2010     Florida   0.6101      7.0
#
#    final_checker  PolicyState   Post
# 0              7         True  False
# 1              7         True  False
# 2              7         True  False
# 3              7         True  False
# 4              7         True   True

# %%
# Convert to CSV
merge_final.to_csv(
    r"D:/Duke University (MIDS 2022)/Fall 2020/IDS 720/Team Project/SHIPMENT_merge_v2.csv",
    index=False,
    header=True,
)
